# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## LOADING THE DATASET

# %%
dataset = pd.read_csv("covid_19_clean_complete.csv")
dataset
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.939110  67.709953  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100  2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388  2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300  2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100  2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600  2020-07-27
#
# ...

# %% [markdown]
# ## EXPLORING DATASET

# %%
dataset.head(50)
# Out:
#                   Province/State            Country/Region        Lat  \
# 0                            NaN               Afghanistan  33.939110
# 1                            NaN                   Albania  41.153300
# 2                            NaN                   Algeria  28.033900
# 3                            NaN                   Andorra  42.506300
# 4                            NaN                    Angola -11.202700
# 5                            NaN       Antigua and Barbuda  17.060800
# 6                            NaN                 Argentina -38.416100
# 7                            NaN                   Armenia  40.069100
# 8   Australian Capital Territory                 Australia -35.473500
# 9                New South Wales                 Australia -33.868800
# 10            Northern Territory                 Australia -12.463400
# 11                    Queensland                 Australia -27.469800
# ...

# %%
dataset.tail(50)
# Out:
#                     Province/State         Country/Region        Lat  \
# 49018                          NaN                 Turkey  38.963700
# 49019                          NaN                 Uganda   1.373333
# 49020                          NaN                Ukraine  48.379400
# 49021                          NaN   United Arab Emirates  23.424076
# 49022                      Bermuda         United Kingdom  32.307800
# 49023               Cayman Islands         United Kingdom  19.313300
# 49024              Channel Islands         United Kingdom  49.372300
# 49025                    Gibraltar         United Kingdom  36.140800
# 49026                  Isle of Man         United Kingdom  54.236100
# 49027                   Montserrat         United Kingdom  16.742498
# 49028                          NaN         United Kingdom  55.378100
# 49029                          NaN                Uruguay -32.522800
# 49030                          NaN                     US  40.000000
# ...

# %% [markdown]
# ## INITIAL ANALYSIS

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %%
dataset.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %% [markdown]
# ## CHANGING THE COLUMN NAMES

# %%
col_names = ['_province_state', '_country_region', 'lat', 'long', 'date', 'confirmed', 'deaths', 'recovered', 'active', 'who_region']
dataset.columns = col_names
col_names
# Out:
# ['_province_state',
#  '_country_region',
#  'lat',
#  'long',
#  'date',
#  'confirmed',
#  'deaths',
#  'recovered',
#  'active',
#  'who_region']

# %%
dataset
# Out:
#       _province_state        _country_region        lat       long  \
# 0                 NaN            Afghanistan  33.939110  67.709953
# 1                 NaN                Albania  41.153300  20.168300
# 2                 NaN                Algeria  28.033900   1.659600
# 3                 NaN                Andorra  42.506300   1.521800
# 4                 NaN                 Angola -11.202700  17.873900
# ...               ...                    ...        ...        ...
# 49063             NaN  Sao Tome and Principe   0.186400   6.613100
# 49064             NaN                  Yemen  15.552727  48.516388
# 49065             NaN                Comoros -11.645500  43.333300
# 49066             NaN             Tajikistan  38.861000  71.276100
# 49067             NaN                Lesotho -29.610000  28.233600
#
#              date  confirmed  deaths  recovered  active             who_region
# 0      2020-01-22          0       0          0       0  Eastern Mediterranean
# ...

# %%
dataset._province_state.unique()
# Out:
# array([nan, 'Australian Capital Territory', 'New South Wales',
#        'Northern Territory', 'Queensland', 'South Australia', 'Tasmania',
#        'Victoria', 'Western Australia', 'Alberta', 'British Columbia',
#        'Manitoba', 'New Brunswick', 'Newfoundland and Labrador',
#        'Nova Scotia', 'Ontario', 'Prince Edward Island', 'Quebec',
#        'Saskatchewan', 'Anhui', 'Beijing', 'Chongqing', 'Fujian', 'Gansu',
#        'Guangdong', 'Guangxi', 'Guizhou', 'Hainan', 'Hebei',
#        'Heilongjiang', 'Henan', 'Hong Kong', 'Hubei', 'Hunan',
#        'Inner Mongolia', 'Jiangsu', 'Jiangxi', 'Jilin', 'Liaoning',
#        'Macau', 'Ningxia', 'Qinghai', 'Shaanxi', 'Shandong', 'Shanghai',
#        'Shanxi', 'Sichuan', 'Tianjin', 'Tibet', 'Xinjiang', 'Yunnan',
#        'Zhejiang', 'Faroe Islands', 'Greenland', 'French Guiana',
#        'French Polynesia', 'Guadeloupe', 'Mayotte', 'New Caledonia',
#        'Reunion', 'Saint Barthelemy', 'St Martin', 'Martinique', 'Aruba',
# ...

# %%
most_province_state = dataset["_province_state"].value_counts()
most_province_state
# Out:
# _province_state
# Australian Capital Territory    188
# New South Wales                 188
# Northern Territory              188
# Queensland                      188
# South Australia                 188
#                                ...
# Anguilla                        188
# British Virgin Islands          188
# Turks and Caicos Islands        188
# Falkland Islands (Malvinas)     188
# Saint Pierre and Miquelon       188
# Name: count, Length: 78, dtype: int64

# %%
dataset.fillna({"_province_state":dataset["_province_state"].mode()[0]}, inplace=True)

# %%
dataset
# Out:
#       _province_state        _country_region        lat       long  \
# 0             Alberta            Afghanistan  33.939110  67.709953
# 1             Alberta                Albania  41.153300  20.168300
# 2             Alberta                Algeria  28.033900   1.659600
# 3             Alberta                Andorra  42.506300   1.521800
# 4             Alberta                 Angola -11.202700  17.873900
# ...               ...                    ...        ...        ...
# 49063         Alberta  Sao Tome and Principe   0.186400   6.613100
# 49064         Alberta                  Yemen  15.552727  48.516388
# 49065         Alberta                Comoros -11.645500  43.333300
# 49066         Alberta             Tajikistan  38.861000  71.276100
# 49067         Alberta                Lesotho -29.610000  28.233600
#
#              date  confirmed  deaths  recovered  active             who_region
# 0      2020-01-22          0       0          0       0  Eastern Mediterranean
# ...
